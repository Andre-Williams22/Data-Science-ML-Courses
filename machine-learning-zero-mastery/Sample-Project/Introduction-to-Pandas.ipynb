# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(['BMW', 'Toyota', 'Tesla', 'Audi'])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Tesla
# 3      Audi
# dtype: object

# %%
# series = 1-dimensional

# %%
colors = pd.Series(["Black", 'Red', 'Blue', 'White'])
colors
# Out:
# 0    Black
# 1      Red
# 2     Blue
# 3    White
# dtype: object

# %%
# DataFrame = 2-dimensional 
car_data = pd.DataFrame({"Car Model": series, "Color": colors})
car_data
# Out:
#   Car Model  Color
# 0       BMW  Black
# 1    Toyota    Red
# 2     Tesla   Blue
# 3      Audi  White

# %%
# Import data
df = pd.read_csv('../Datasets/car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.describe(include='all')
# Out:
#           Make Colour  Odometer (KM)      Doors      Price
# count       10     10      10.000000  10.000000         10
# unique       4      5            NaN        NaN          9
# top     Toyota  White            NaN        NaN  $7,000.00
# freq         4      4            NaN        NaN          2
# mean       NaN    NaN   78601.400000   4.000000        NaN
# std        NaN    NaN   61983.471735   0.471405        NaN
# min        NaN    NaN   11179.000000   3.000000        NaN
# 25%        NaN    NaN   35836.250000   4.000000        NaN
# 50%        NaN    NaN   57369.000000   4.000000        NaN
# 75%        NaN    NaN   96384.500000   4.000000        NaN
# max        NaN    NaN  213095.000000   5.000000        NaN

# %%
df.isnull().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
# Exporting a dataframe 
df.to_csv('exported-car-sales.csv', index=False)

# %%
export_car_sales = pd.read_csv('exported-car-sales.csv')
car_sales = export_car_sales
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attribute - meta info about dataset
car_sales.dtypes

# Function - this performs steps 
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe(include='all')
# Out:
#           Make Colour  Odometer (KM)      Doors      Price
# count       10     10      10.000000  10.000000         10
# unique       4      5            NaN        NaN          9
# top     Toyota  White            NaN        NaN  $7,000.00
# freq         4      4            NaN        NaN          2
# mean       NaN    NaN   78601.400000   4.000000        NaN
# std        NaN    NaN   61983.471735   0.471405        NaN
# min        NaN    NaN   11179.000000   3.000000        NaN
# 25%        NaN    NaN   35836.250000   4.000000        NaN
# 50%        NaN    NaN   57369.000000   4.000000        NaN
# 75%        NaN    NaN   96384.500000   4.000000        NaN
# max        NaN    NaN  213095.000000   5.000000        NaN

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 15000, 11230])
car_prices.mean()
# Out:
# 9743.333333333334

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
#  ## Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.sample(5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# 1                 4                True
# 7                 4                True
# 3                 4                True
# 4                 4                True

# %%
# .loc
animals = pd.Series(["cat", 'dog', 'bird', 'lion', 'panda'], index=[0, 3, 9, 8, 3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8     lion
# 3    panda
# dtype: object

# %%
animals.loc[3] # loc = location
# Out:
# 3      dog
# 3    panda
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8     lion
# 3    panda
# dtype: object

# %%
# iloc refers to position
animals.iloc[3]
# Out:
# 'lion'

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8     lion
# 3    panda
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
## Filtering
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean() # finds mean of all categories in Make column
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# change price object to integers
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'].plot()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %% [markdown]
# ## Replacing Missing Values

# %%
car_sales_missing = pd.read_csv("../Datasets/car-sales-missing-values.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
# this fills the missing values with car sales missing odometer mean value 
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
# or 
#car_sales_missing['Odometer'] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## Drop Missing Values

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %% [markdown]
# ## Create Column in Data

# %%
# create new column
seats_column = pd.Series([5,5,5,5,5])

# New Column called seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    NaN       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    NaN       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    NaN       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    NaN       7.5          7.5
# 9  NISSAN  White          31600      4   970000    NaN       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
car_sales["Seats"].fillna(7, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
# Columns from Python list
# the list has to be same length as other columns
fuel_economy = [7.6, 3, 5.0, 9.6, 8.7, 9.1, 3.4, 6.7, 7.5, 7.7 ]
car_sales['Fuel per KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
# let's create a column from another column 
car_sales["Total fuel used"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel MPH"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety  Total fuel used
# ...

# %%
# Create a columns from a single value 
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety  Total fuel used
# ...

# %%
car_sales["Passed Road Safety"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int64
# Seats                 float64
# Fuel MPH              float64
# Fuel per KM           float64
# Number of Wheels        int64
# Passed Road Safety       bool
# Total fuel used       float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety  Total fuel used
# ...

# %% [markdown]
# ## Let's delete columns

# %%
car_sales = car_sales.drop("Total fuel used", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
car_sales.sample(frac=1) # 1 = 100% of data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
#
#    Number of Wheels  Passed Road Safety
# 9                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
#
#    Number of Wheels  Passed Road Safety
# 3                 4                True
# ...

# %%
# only select 20% of data 
car_sales_shuffled.sample(frac=.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel MPH  Fuel per KM  \
# 5  TOYOTA  Green          99213      4  450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4  750000    7.0       3.4          3.4
#
#    Number of Wheels  Passed Road Safety
# 5                 4                True
# 6                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 1   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 2  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 3  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 4   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 5  NISSAN  White          31600      4   970000    7.0       7.7          7.7
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 8  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 9  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White         150043      4   400000    5.0       7.6          7.6
# 1   HONDA    Red          87899      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue          32549      3   700000    5.0       5.0          5.0
# 3     BMW  Black          11179      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White         213095      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green          99213      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue          45698      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue          54738      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White          60000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White          31600      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %%
# apply is a way to assign a function to a column 
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel MPH  Fuel per KM  \
# 0  TOYOTA  White      93776.875      4   400000    5.0       7.6          7.6
# 1   HONDA    Red      54936.875      4   500000    5.0       3.0          3.0
# 2  TOYOTA   Blue      20343.125      3   700000    5.0       5.0          5.0
# 3     BMW  Black       6986.875      5  2200000    5.0       9.6          9.6
# 4  NISSAN  White     133184.375      4   350000    5.0       8.7          8.7
# 5  TOYOTA  Green      62008.125      4   450000    7.0       9.1          9.1
# 6   HONDA   Blue      28561.250      4   750000    7.0       3.4          3.4
# 7   HONDA   Blue      34211.250      4   700000    7.0       6.7          6.7
# 8  TOYOTA  White      37500.000      4   625000    7.0       7.5          7.5
# 9  NISSAN  White      19750.000      4   970000    7.0       7.7          7.7
#
#    Number of Wheels  Passed Road Safety
# 0                 4                True
# ...

# %% [markdown]
# ## Steps
# - try it, run your code
# - search for it
# - try again
# - ask
